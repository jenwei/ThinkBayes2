# %%
import thinkstats2
import thinkplot

# %%
dice6 = thinkstats2.Pmf(range(1,7))

# %%
thinkplot.Pmf(dice6)

# %%
thinkplot.Hist(dice6)

# %%
two = dice6+dice6
thinkplot.Hist(two)

# %%
three = two+dice6
thinkplot.Hist(three)

# %%
four=three+dice6
thinkplot.Hist(four)

# %%
five=four+dice6
thinkplot.Hist(five)

# %%
thinkplot.Pdfs([dice6,two,three,four,five])

# %%
eight=four+four

# %%
eight.Prob(30)
# Out:
# 0.0747718526139308

# %%
eight[30]
# Out:
# 0.0747718526139308

# %%
eight.ProbGreater(30)
# Out:
# 0.3054001628943758

# %%
eight.ProbGreater(four)
#bugggg?
# Out:
# 0.9999999999999999

# %%
three.ProbGreater(15) #16 or greater
# Out:
# 0.046296296296296294

# %%
1-three.ProbLess(16)
# Out:
# 0.04629629629629639

# %%
for attribute in ['strength','intelligence','wisdom','dexterity','constitution','charisma']:
    print attribute,three.Random()
# Out:
# strength 16
# intelligence 5
# wisdom 12
# dexterity 13
# constitution 9
# charisma 12

# %%
three.Mean()
# Out:
# 10.500000000000002

# %%
variance=three.Var()
print variance
# Out:
# 8.75

# %%
three.Var()
# Out:
# 8.749999999999998

# %%
sd = variance**(1/2.0)
print sd
# Out:
# 2.95803989155

# %% [markdown]
# # Note: a modification to the thinkbayes2 code took place after this, so some of this code might need some tweaking.
